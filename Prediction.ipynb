# %%
# !pip install -U segmentation-models
# Out:
# Requirement already satisfied: segmentation-models in c:\users\dell\anaconda3\envs\tf\lib\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from efficientnet==1.0.0->segmentation-models) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.26.4)
# Requirement already satisfied: h5py in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.14.0)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.16.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.5)
# Requirement already satisfied: pillow>=10.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2025.8.28)
# Requirement already satisfied: packaging>=21 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.4)

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\dell\anaconda3\envs\tf\lib\site-packages (5.44.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.12.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.34.4)
# Requirement already satisfied: jinja2<4.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (3.11.3)
# Requirement already satisfied: packaging in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.12.11)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.17.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in c:\users\dell\appdata\roaming\python\python312\site-packages (from gradio-client==1.12.1->gradio) (2025.5.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from gradio-client==1.12.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\dell\appdata\roaming\python\python312\site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpx<1.0,>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dell\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.18.0)
# Requirement already satisfied: requests in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from typer<1.0,>=0.12->gradio) (14.1.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python312\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (2.2.3)

# %%
import os
import cv2
from PIL import Image 
import numpy as np

# %%
from matplotlib import pyplot as plt
import random

# %%
# !pip install -U segmentation-models
# Out:
# Requirement already satisfied: segmentation-models in c:\users\dell\anaconda3\envs\tf\lib\site-packages (1.0.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: image-classifiers==1.0.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: scikit-image in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from efficientnet==1.0.0->segmentation-models) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.26.4)
# Requirement already satisfied: h5py in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.14.0)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.16.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.5)
# Requirement already satisfied: pillow>=10.1 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2025.8.28)
# Requirement already satisfied: packaging>=21 in c:\users\dell\appdata\roaming\python\python312\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\dell\anaconda3\envs\tf\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (0.4)

# %%
from keras.models import load_model

# %%
import gradio as gr

# %%
from keras import backend as K
from keras.models import load_model

# %%
def process_input_image(image_source):
  image = np.expand_dims(image_source, 0)

  prediction = saved_model.predict(image)
  predicted_image = np.argmax(prediction, axis=3)

  predicted_image = predicted_image[0,:,:]
  predicted_image = predicted_image * 50
  return 'Predicted Masked Image', predicted_image
